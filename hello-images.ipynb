# %%
import os
from nilearn import plotting
from nilearn import image

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
path = '/Users/fangfang/Downloads/GO-TBI7'
file1 = os.path.join(path, 'hardi.nii.gz')

# %%
path = '/Users/fangfang/Downloads/GO-TBI7'
file2 = os.path.join(path, 'rsfmri.nii.gz')

# %%
img1 = image.load_img(file1)

# %%
print(img1.shape)
# Out:
# (256, 256, 72, 62)

# %%
img2 = image.load_img(file2)
print(img2.shape)
# Out:
# (64, 64, 35, 200)

# %%
first1 = image.index_img(img1, 0)
print(first1.shape)
# Out:
# (256, 256, 72)

# %%
plotting.plot_stat_map(first1)

# %%
first2 = image.index_img(img2, 0)
print(first2.shape)
plotting.plot_stat_map(first2)
# Out:
# (64, 64, 35)

# %%
file3 = os.path.join(path, 'anat.nii.gz')
img3 = image.load_img(file3)
print(img3.shape)
plotting.plot_stat_map(img3)
# Out:
# (149, 196, 185)
